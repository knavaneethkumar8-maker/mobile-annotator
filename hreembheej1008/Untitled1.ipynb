# %%
# !python3 run_all.py
# Out:
# python3: can't open file '/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py': [Errno 2] No such file or directory

# %%
# !python3 "/data_disk/team/abhinav/open this/hreembheej1008/run_all.py"
# Out:
# python3: can't open file '/data_disk/team/abhinav/open this/hreembheej1008/run_all.py': [Errno 2] No such file or directory

# %%
import os
os.chdir("/data_disk/team/abhinav/open this/hreembheej1008")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 os.chdir("/data_disk/team/abhinav/open this/hreembheej1008")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data_disk/team/abhinav/open this/hreembheej1008'

# %%
# !pwd
# Out:
# /mnt/data_disk/team/abhinav/open this/hreembheej1008

# %%
# !ls
# Out:
# ' run_all.py'		 hreem_4x_chunk030.wav	     hreem_normal_chunk016.wav
#  Untitled.ipynb		 hreem_4x_chunk031.wav	     hreem_normal_chunk017.wav
#  Untitled1.ipynb	 hreem_4x_chunk032.wav	     hreem_normal_chunk018.wav
#  hreem_4x_chunk001.wav	 hreem_4x_chunk033.wav	     hreem_normal_chunk019.wav
#  hreem_4x_chunk002.wav	 hreem_4x_chunk034.wav	     hreem_normal_chunk020.wav
#  hreem_4x_chunk003.wav	 hreem_4x_chunk035.wav	     hreem_normal_chunk021.wav
#  hreem_4x_chunk004.wav	 hreem_4x_chunk036.wav	     hreem_normal_chunk022.wav
#  hreem_4x_chunk005.wav	 hreem_4x_chunk037.wav	     hreem_normal_chunk023.wav
#  hreem_4x_chunk006.wav	 hreem_4x_chunk038.wav	     hreem_normal_chunk024.wav
#  hreem_4x_chunk007.wav	 hreem_4x_chunk039.wav	     hreem_normal_chunk025.wav
#  hreem_4x_chunk008.wav	 hreem_4x_chunk040.wav	     hreem_normal_chunk026.wav
#  hreem_4x_chunk009.wav	 hreem_4x_chunk041.wav	     hreem_normal_chunk027.wav
# ...

# %%
# !ls "/mnt/data_disk/team/abhinav/open this/"
# Out:
# '1008 dham abhi'		 akshar_pipeline.ipynb	 humming_dataset
#  ALL_LANG_MAPPING.tsv		 clean_mapping.tsv	 kham2.wav
#  FINAL_ALL_LANG.tsv		 datasets		 mau_detection.ipynb
#  FINAL_ALL_LANG_CORRECT.tsv	 dham.wav		 metadata
#  FINAL_ALL_LANG_FIXED.tsv	 dictionary.tsv		 music.wav
#  FINAL_DICTIONARY.tsv		 final_clean.tsv	 processed_audio
#  FINAL_DICTIONARY_ALL_LANG.tsv	 final_correct.tsv	 ready_mapping.tsv
#  FINAL_DICTIONARY_CLEAN.tsv	 final_final.tsv	 scripts
#  FINAL_MAPPING.tsv		 final_mapping.tsv	 tam.wav
#  Untitled.ipynb			 hreembheej1008

# %%
import os
os.chdir("/mnt/data_disk/team/abhinav/open this/hreembeej1008")

# !python3 run_all.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import os
# ----> 2 os.chdir("/mnt/data_disk/team/abhinav/open this/hreembeej1008")
#       4 get_ipython().system('python3 run_all.py')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data_disk/team/abhinav/open this/hreembeej1008'

# %%
# !ls
# Out:
# ' run_all.py'		 hreem_4x_chunk030.wav	     hreem_normal_chunk016.wav
#  Untitled.ipynb		 hreem_4x_chunk031.wav	     hreem_normal_chunk017.wav
#  Untitled1.ipynb	 hreem_4x_chunk032.wav	     hreem_normal_chunk018.wav
#  hreem_4x_chunk001.wav	 hreem_4x_chunk033.wav	     hreem_normal_chunk019.wav
#  hreem_4x_chunk002.wav	 hreem_4x_chunk034.wav	     hreem_normal_chunk020.wav
#  hreem_4x_chunk003.wav	 hreem_4x_chunk035.wav	     hreem_normal_chunk021.wav
#  hreem_4x_chunk004.wav	 hreem_4x_chunk036.wav	     hreem_normal_chunk022.wav
#  hreem_4x_chunk005.wav	 hreem_4x_chunk037.wav	     hreem_normal_chunk023.wav
#  hreem_4x_chunk006.wav	 hreem_4x_chunk038.wav	     hreem_normal_chunk024.wav
#  hreem_4x_chunk007.wav	 hreem_4x_chunk039.wav	     hreem_normal_chunk025.wav
#  hreem_4x_chunk008.wav	 hreem_4x_chunk040.wav	     hreem_normal_chunk026.wav
#  hreem_4x_chunk009.wav	 hreem_4x_chunk041.wav	     hreem_normal_chunk027.wav
# ...

# %%
# !cd hreembeej1008 && python3 run_all.py
# Out:
# /bin/sh: 1: cd: can't cd to hreembeej1008

# %%
# !python3 run_all.py
# Out:
# python3: can't open file '/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py': [Errno 2] No such file or directory

# %%
# !pwd
# Out:
# /mnt/data_disk/team/abhinav/open this/hreembheej1008

# %%
# %cd ..
# Out:
# /mnt/data_disk/team/abhinav/open this
# /root/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# '1008 dham abhi'		 akshar_pipeline.ipynb	 humming_dataset
#  ALL_LANG_MAPPING.tsv		 clean_mapping.tsv	 kham2.wav
#  FINAL_ALL_LANG.tsv		 datasets		 mau_detection.ipynb
#  FINAL_ALL_LANG_CORRECT.tsv	 dham.wav		 metadata
#  FINAL_ALL_LANG_FIXED.tsv	 dictionary.tsv		 music.wav
#  FINAL_DICTIONARY.tsv		 final_clean.tsv	 processed_audio
#  FINAL_DICTIONARY_ALL_LANG.tsv	 final_correct.tsv	 ready_mapping.tsv
#  FINAL_DICTIONARY_CLEAN.tsv	 final_final.tsv	 scripts
#  FINAL_MAPPING.tsv		 final_mapping.tsv	 tam.wav
#  Untitled.ipynb			 hreembheej1008

# %%
# %cd hreembheej1008
# Out:
# /mnt/data_disk/team/abhinav/open this/hreembheej1008

# %%
# !ls
# Out:
# ' run_all.py'		 hreem_4x_chunk030.wav	     hreem_normal_chunk016.wav
#  Untitled.ipynb		 hreem_4x_chunk031.wav	     hreem_normal_chunk017.wav
#  Untitled1.ipynb	 hreem_4x_chunk032.wav	     hreem_normal_chunk018.wav
#  hreem_4x_chunk001.wav	 hreem_4x_chunk033.wav	     hreem_normal_chunk019.wav
#  hreem_4x_chunk002.wav	 hreem_4x_chunk034.wav	     hreem_normal_chunk020.wav
#  hreem_4x_chunk003.wav	 hreem_4x_chunk035.wav	     hreem_normal_chunk021.wav
#  hreem_4x_chunk004.wav	 hreem_4x_chunk036.wav	     hreem_normal_chunk022.wav
#  hreem_4x_chunk005.wav	 hreem_4x_chunk037.wav	     hreem_normal_chunk023.wav
#  hreem_4x_chunk006.wav	 hreem_4x_chunk038.wav	     hreem_normal_chunk024.wav
#  hreem_4x_chunk007.wav	 hreem_4x_chunk039.wav	     hreem_normal_chunk025.wav
#  hreem_4x_chunk008.wav	 hreem_4x_chunk040.wav	     hreem_normal_chunk026.wav
#  hreem_4x_chunk009.wav	 hreem_4x_chunk041.wav	     hreem_normal_chunk027.wav
# ...

# %%
# !python3 run_all.py
# Out:
# python3: can't open file '/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py': [Errno 2] No such file or directory

# %%
# !mv " run_all.py" run_all.py

# %%
# !ls
# Out:
# Untitled.ipynb	       hreem_4x_chunk031.wav	  hreem_normal_chunk017.wav
# Untitled1.ipynb        hreem_4x_chunk032.wav	  hreem_normal_chunk018.wav
# hreem_4x_chunk001.wav  hreem_4x_chunk033.wav	  hreem_normal_chunk019.wav
# hreem_4x_chunk002.wav  hreem_4x_chunk034.wav	  hreem_normal_chunk020.wav
# hreem_4x_chunk003.wav  hreem_4x_chunk035.wav	  hreem_normal_chunk021.wav
# hreem_4x_chunk004.wav  hreem_4x_chunk036.wav	  hreem_normal_chunk022.wav
# hreem_4x_chunk005.wav  hreem_4x_chunk037.wav	  hreem_normal_chunk023.wav
# hreem_4x_chunk006.wav  hreem_4x_chunk038.wav	  hreem_normal_chunk024.wav
# hreem_4x_chunk007.wav  hreem_4x_chunk039.wav	  hreem_normal_chunk025.wav
# hreem_4x_chunk008.wav  hreem_4x_chunk040.wav	  hreem_normal_chunk026.wav
# hreem_4x_chunk009.wav  hreem_4x_chunk041.wav	  hreem_normal_chunk027.wav
# hreem_4x_chunk010.wav  hreem_4x_chunk042.wav	  hreem_normal_chunk028.wav
# hreem_4x_chunk011.wav  hreem_4x_chunk043.wav	  hreem_normal_chunk029.wav
# ...

# %%
# !python3 run_all.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 134, in <module>
#     run_all()
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 130, in run_all
#     process_file(file, model)
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 90, in process_file
#     p = torch.softmax(model(batch), dim=1)[:,1].cpu().numpy()
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 35, in forward
#     out,_=self.lstm(x)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
# ...

# %%
# !python3 run_all.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 134, in <module>
#     run_all()
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 130, in run_all
#     process_file(file, model)
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 90, in process_file
#     p = torch.softmax(model(batch), dim=1)[:,1].cpu().numpy()
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/data_disk/team/abhinav/open this/hreembheej1008/run_all.py", line 35, in forward
#     out,_=self.lstm(x)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
# ...

# %%
# !mkdir -p "/data_disk2/team/abhinav"

# %%
# !mv "/data_disk/team/abhinav/open this/hreembheej1008" "/data_disk2/team/abhinav/"
# Out:
# mv: cannot stat '/data_disk/team/abhinav/open this/hreembheej1008': No such file or directory

# %%
# !mv "/data_disk/team/abhinav/open this/hreembeej1008" "/data_disk2/team/abhinav/"
# Out:
# mv: cannot stat '/data_disk/team/abhinav/open this/hreembeej1008': No such file or directory

# %%
# !mv "/mnt/data_disk/team/abhinav/open this/hreembeej1008" "/data_disk2/team/abhinav/"
# Out:
# mv: cannot stat '/mnt/data_disk/team/abhinav/open this/hreembeej1008': No such file or directory

# %%
# %cd /mnt/data_disk_2/abhi/hreembheej1008
# Out:
# /mnt/data_disk_2/abhi/hreembheej1008
# /root/miniconda3/envs/jupyter_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# Untitled.ipynb	       hreem_4x_chunk031.wav	  hreem_normal_chunk017.wav
# Untitled1.ipynb        hreem_4x_chunk032.wav	  hreem_normal_chunk018.wav
# hreem_4x_chunk001.wav  hreem_4x_chunk033.wav	  hreem_normal_chunk019.wav
# hreem_4x_chunk002.wav  hreem_4x_chunk034.wav	  hreem_normal_chunk020.wav
# hreem_4x_chunk003.wav  hreem_4x_chunk035.wav	  hreem_normal_chunk021.wav
# hreem_4x_chunk004.wav  hreem_4x_chunk036.wav	  hreem_normal_chunk022.wav
# hreem_4x_chunk005.wav  hreem_4x_chunk037.wav	  hreem_normal_chunk023.wav
# hreem_4x_chunk006.wav  hreem_4x_chunk038.wav	  hreem_normal_chunk024.wav
# hreem_4x_chunk007.wav  hreem_4x_chunk039.wav	  hreem_normal_chunk025.wav
# hreem_4x_chunk008.wav  hreem_4x_chunk040.wav	  hreem_normal_chunk026.wav
# hreem_4x_chunk009.wav  hreem_4x_chunk041.wav	  hreem_normal_chunk027.wav
# hreem_4x_chunk010.wav  hreem_4x_chunk042.wav	  hreem_normal_chunk028.wav
# hreem_4x_chunk011.wav  hreem_4x_chunk043.wav	  hreem_normal_chunk029.wav
# ...

# %%
# !python3 run_all.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/data_disk_2/abhi/hreembheej1008/run_all.py", line 134, in <module>
#     run_all()
#   File "/mnt/data_disk_2/abhi/hreembheej1008/run_all.py", line 130, in run_all
#     process_file(file, model)
#   File "/mnt/data_disk_2/abhi/hreembheej1008/run_all.py", line 90, in process_file
#     p = torch.softmax(model(batch), dim=1)[:,1].cpu().numpy()
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/data_disk_2/abhi/hreembheej1008/run_all.py", line 35, in forward
#     out,_=self.lstm(x)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
# ...
